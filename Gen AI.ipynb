# %% [markdown]
# # BERT Model

# %%
from transformers import pipeline


pipeline = pipeline(
    task="fill-mask",
    model="google-bert/bert-base-uncased",
    device=0
)
# Out:
# ...
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  440MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] BertForMaskedLM LOAD REPORT from: google-bert/bert-base-uncased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# cls.seq_relationship.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [{'score': 0.1511750966310501,
#   'token': 2943,
# ...

# %%
pred = pipeline("The sun rises in the [MASK]")

# %%
for x in pred:
    print(x)
# Out:
# {'score': 0.2557116150856018, 'token': 3712, 'token_str': 'sky', 'sequence': 'the sun rises in the sky'}
# {'score': 0.1827753484249115, 'token': 2264, 'token_str': 'east', 'sequence': 'the sun rises in the east'}
# {'score': 0.16991201043128967, 'token': 2225, 'token_str': 'west', 'sequence': 'the sun rises in the west'}
# {'score': 0.06708882749080658, 'token': 2851, 'token_str': 'morning', 'sequence': 'the sun rises in the morning'}
# {'score': 0.03479623422026634, 'token': 2167, 'token_str': 'north', 'sequence': 'the sun rises in the north'}

# %%
for x in pred:
    print(x['sequence'])
# Out:
# the sun rises in the sky
# the sun rises in the east
# the sun rises in the west
# the sun rises in the morning
# the sun rises in the north

# %%
from transformers import pipeline


pipeline = pipeline(
    task="fill-mask",
    model="google-bert/bert-base-uncased",
    device=0
)

pipeline("The sun rises in the [MASK]")[0]['sequence']
# Out:
# 'the sun rises in the sky'

# %%
pred[1]['sequence']
# Out:
# 'the sun rises in the east'

# %%
pred[2]['sequence']
# Out:
# 'the sun rises in the west'

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="openai-community/gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe("Hello, I'm a language model")
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %% [markdown]
# # GPT Model

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer


tokenizer = AutoTokenizer.from_pretrained(
    "google-t5/t5-base"
    )
model = AutoModelForSeq2SeqLM.from_pretrained(
    "google-t5/t5-base",
    device_map="auto"
    )
# Out:
# ...
# model.safetensors: reconstructing file:   0%|          |  0.00B /  892MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/257 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# # T5 Model

# %%
val = "Le temps est agréable aujourd'hui."

# %%
print('*' * 40)
print('Translater model..... English, French, Romanian, German')
print('*' * 40)
user_input = input('Enter text to translate : ')
input_ids = tokenizer("translate to English:" + user_input, return_tensors="pt").to(model.device)

output = model.generate(**input_ids, cache_implementation="static")
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# ****************************************
# Translater model..... English, French, Romanian, German
# ****************************************
# Enter text to translate :  Hier ist ein einfacher deutscher
