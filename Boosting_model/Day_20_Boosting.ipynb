# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,  f1_score

# %%
df = pd.read_csv(r'customer_churn_dataset.csv')
df.head()
# Out:
#    CustomerID  Tenure  MonthlyCharges  TotalCharges ContractType TechSupport  \
# 0           1      39           74.42       4265.19     One Year         Yes
# 1           2      52           56.04       2302.31      Monthly          No
# 2           3      29           21.06        567.51      Monthly         Yes
# 3           4      15           95.38       1917.01     Two Year          No
# 4           5      43           65.06       3377.32     One Year          No
#
#   Complaints Churn
# 0         No    No
# 1         No   Yes
# 2        Yes    No
# 3        Yes    No
# 4         No    No

# %%
col = ['ContractType','TechSupport','Complaints','Churn']

encoding = LabelEncoder()

for x in col:
    df[x] = encoding.fit_transform(df[x])
df.head()
# Out:
#    CustomerID  Tenure  MonthlyCharges  TotalCharges  ContractType  \
# 0           1      39           74.42       4265.19             1
# 1           2      52           56.04       2302.31             0
# 2           3      29           21.06        567.51             0
# 3           4      15           95.38       1917.01             2
# 4           5      43           65.06       3377.32             1
#
#    TechSupport  Complaints  Churn
# 0            1           0      0
# 1            0           0      1
# 2            1           1      0
# 3            0           1      0
# 4            0           0      0

# %%
X = df.drop(['CustomerID','Churn'], axis=1)
y = df['Churn']

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size=0.2, random_state=20)
y_test.value_counts()
# Out:
# Churn
# 0    6
# 1    6
# Name: count, dtype: int64

# %%
col = ('Tenure','MonthlyCharges','TotalCharges')
model = StandardScaler()
for val in col:
   X_test[val] =  model.fit_transform(X_test[[val]])

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f'Accuracy : {accuracy_score(y_test, y_pred)} | F1 Score : {f1_score(y_test,y_pred)}')
# Out:
# Accuracy : 0.5833333333333334 | F1 Score : 0.4444444444444444

# %%
model = GradientBoostingClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f'Accuracy : {accuracy_score(y_test, y_pred)} | F1 Score : {f1_score(y_test,y_pred)}')
# Out:
# Accuracy : 0.5 | F1 Score : 0.0

# %%
model = AdaBoostClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f'Accuracy : {accuracy_score(y_test, y_pred)} | F1 Score : {f1_score(y_test,y_pred)}')
# Out:
# Accuracy : 0.6666666666666666 | F1 Score : 0.7142857142857143

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f'Accuracy : {accuracy_score(y_test, y_pred)} | F1 Score : {f1_score(y_test,y_pred)}')
# Out:
# Accuracy : 0.6666666666666666 | F1 Score : 0.7142857142857143

# %%
model = LGBMClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f'Accuracy : {accuracy_score(y_test, y_pred)} | F1 Score : {f1_score(y_test,y_pred)}')
# Out:
# [LightGBM] [Info] Number of positive: 14, number of negative: 32
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000267 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51
# [LightGBM] [Info] Number of data points in the train set: 46, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.304348 -> initscore=-0.826679
# [LightGBM] [Info] Start training from score -0.826679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model = CatBoostClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(f'Accuracy : {accuracy_score(y_test, y_pred)} | F1 Score : {f1_score(y_test,y_pred)}')
# Out:
# Learning rate set to 0.002767
# 0:	learn: 0.6919578	total: 55.9ms	remaining: 55.9s
# 1:	learn: 0.6911675	total: 56.3ms	remaining: 28.1s
# 2:	learn: 0.6894036	total: 56.7ms	remaining: 18.8s
# 3:	learn: 0.6879461	total: 57.1ms	remaining: 14.2s
# 4:	learn: 0.6867853	total: 57.5ms	remaining: 11.4s
# 5:	learn: 0.6855205	total: 57.8ms	remaining: 9.58s
# 6:	learn: 0.6839601	total: 58.2ms	remaining: 8.26s
# 7:	learn: 0.6829724	total: 58.4ms	remaining: 7.24s
# 8:	learn: 0.6814935	total: 58.8ms	remaining: 6.47s
# 9:	learn: 0.6795362	total: 59.1ms	remaining: 5.85s
# 10:	learn: 0.6783414	total: 59.4ms	remaining: 5.34s
# 11:	learn: 0.6768813	total: 59.7ms	remaining: 4.91s
# 12:	learn: 0.6759014	total: 60ms	remaining: 4.56s
# 13:	learn: 0.6739698	total: 60.3ms	remaining: 4.25s
# 14:	learn: 0.6724619	total: 60.8ms	remaining: 3.99s
# 15:	learn: 0.6709668	total: 61.2ms	remaining: 3.76s
# 16:	learn: 0.6695341	total: 61.6ms	remaining: 3.56s
# 17:	learn: 0.6683647	total: 61.9ms	remaining: 3.38s
# ...

# %%
import numpy as np
import pandas as pd
 
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import (
    AdaBoostClassifier,
    ExtraTreesClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
 
import numpy as np
import pandas as pd
 
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import (
    AdaBoostClassifier,
    ExtraTreesClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier
try:
    import importlib
    catboost_module = importlib.import_module("catboost")
    CatBoostClassifier = catboost_module.CatBoostClassifier
except ModuleNotFoundError:
    CatBoostClassifier = None
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
 
 
# 1. LOAD & CLEAN DATA
 
folder_path = r"C:\Users\ASUS\Downloads\Hypo\\"
 
df = pd.read_csv(folder_path+"customer_churn_dataset.csv")
 
print("Data successfully loaded!")
print(df.head())
 
# Drop CustomerID column (irrelevant identifier)
df_clean = df.drop(columns=['CustomerID'])
 
# Map target string labels 'Yes'/'No' to 1/0
X = df_clean.drop(columns=['Churn'])
y = df_clean['Churn'].map({'No': 0, 'Yes': 1})
 
# Define numerical and categorical columns
num_cols = ['Tenure', 'MonthlyCharges', 'TotalCharges']
cat_cols = ['ContractType', 'TechSupport', 'Complaints']
 
 
# 2. PREPROCESSING PIPELINE
 
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), cat_cols),
    ]
)
 
 
# 3. DEFINE MODELS
 
# NOTE: Removed class_weight='balanced' because SMOTE will handle the balancing.
models = {
    'AdaBoost': AdaBoostClassifier(n_estimators=30, random_state=42),
    'RandomForest': RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42),
    'ExtraTrees': ExtraTreesClassifier(n_estimators=100, max_depth=3, random_state=42),
    'NaiveBayes': GaussianNB(),
    'GradientBoosting': GradientBoostingClassifier(n_estimators=30, max_depth=2, random_state=42),
    'DecisionTree': DecisionTreeClassifier(max_depth=3, random_state=42),
    'SVM': SVC(probability=True, random_state=42),
    'KNN': KNeighborsClassifier(n_neighbors=3),
    'LightGBM': LGBMClassifier(n_estimators=30, max_depth=2, random_state=50),
    'CatBoost': CatBoostClassifier(n_estimators=30, max_depth=2, random_state=42, verbose=False),
}
 
 
try:
    from xgboost import XGBClassifier
    models['XGBoost'] = XGBClassifier(
        n_estimators=30,
        max_depth=2,
        random_state=42,
        eval_metric='logloss',
    )
except ImportError:
    pass
 
 
# 4. CROSS-VALIDATION & EVALUATION WITH SMOTE
 
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = []
 
for name, model in models.items():
    # Constructing the ImbPipeline instead of standard sklearn Pipeline
    # Order matters: 1. Transform features -> 2. Synthesize minority samples -> 3. Fit model
    pipeline = ImbPipeline(
        steps=[
            ('preprocessor', preprocessor),
            ('smote', SMOTE(random_state=42)),
            ('classifier', model)
        ]
    )
 
    scores = cross_validate(
        pipeline,
        X,
        y,
        cv=skf,
        scoring=['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
        error_score='raise' # Helps debug immediately if a specific fold crashes
    )
 
    results.append({
        'Model': name,
        'Accuracy': round(np.mean(scores['test_accuracy']), 4),
        'Precision': round(np.mean(scores['test_precision']), 4),
        'Recall': round(np.mean(scores['test_recall']), 4),
        'F1 Score': round(np.mean(scores['test_f1']), 4),
        'ROC AUC': round(np.mean(scores['test_roc_auc']), 4),
    })
 
 
results_df = (
    pd.DataFrame(results)
    .sort_values(by='F1 Score', ascending=False)
    .reset_index(drop=True)
)
print("\n--- Final Model Evaluation Results (Balanced via SMOTE) ---")
display(results_df)
